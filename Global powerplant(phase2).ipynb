# %% [markdown]
# ## Project Description
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.
# Key attributes of the database
# The database includes the following indicators:
#
# •
#
# •	`country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
#
# •	`country_long` (text): longer form of the country designation
#
# •	`name` (text): name or title of the power plant, generally in Romanized form
#
# •	`gppd_idnr` (text): 10 or 12 character identifier for the power plant
#
# •	`capacity_mw` (number): electrical generating capacity in megawatts
#
# •	`latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# •	`longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# •	`primary_fuel` (text): energy source used in primary electricity generation or export
#
# •	`other_fuel1` (text): energy source used in electricity generation or export
#
# •	`other_fuel2` (text): energy source used in electricity generation or export
#
# •	`other_fuel3` (text): energy source used in electricity generation or export
#
# •	 `commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
#
# •	`owner` (text): majority shareholder of the power plant, generally in Romanized form
#
# •	`source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
#
# •	`url` (text): web document corresponding to the `source` field
#
# •	`geolocation_source` (text): attribution for geolocation information
#
# •	`wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
#
# •	`year_of_capacity_data` (number): year the capacity information was reported
#
# •	`generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
#
# •	`generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
#
# •	`generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
#
# •	`generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
#
# •	`generation_gwh_2017` (number): electricity generation in gigawatt-hours reported for the year 2017
#
# •	`generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
#
# •	`generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
#
# •	`generation_data_source` (text): attribution for the reported generation information
#
# •	`estimated_generation_gwh_2013` (number): estimated electricity generation in gigawatt-hours for the year 2013
#
# •	`estimated_generation_gwh_2014` (number): estimated electricity generation in gigawatt-hours for the year 2014
#
# •	`estimated_generation_gwh_2015` (number): estimated electricity generation in gigawatt-hours for the year 2015
#
# •	`estimated_generation_gwh_2016` (number): estimated electricity generation in gigawatt-hours for the year 2016
#
# •	`estimated_generation_gwh_2017` (number): estimated electricity generation in gigawatt-hours for the year 2017
#
# •	'estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
#
# •	`estimated_generation_note_2014` (text): label of the model/method used to estimate generation for the year 2014
#
# •	`estimated_generation_note_2015` (text): label of the model/method used to estimate generation for the year 2015
#
# •	`estimated_generation_note_2016` (text): label of the model/method used to estimate generation for the year 2016
#
# •	`estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the year 2017
#
# Fuel Type Aggregation
#
# We define the "Fuel Type" attribute of our database based on common fuel categories.
# Prediction :   Make two prediction  1) Primary Fuel    2) capacity_mw
#
# Dataset Link-
# •	https://github.com/wri/global-power-plant-database/blob/master/source_databases_csv/database_IND.csv

# %%
# Frist we will upload the necessarhy libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import  warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv')

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
# There are definitely some null values present

# %%
df.isna().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
df.shape
# Out:
# (907, 27)

# %%
df.nunique()
# Out:
# country                       1
# country_long                  1
# name                        907
# gppd_idnr                   907
# capacity_mw                 361
# latitude                    836
# longitude                   827
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013           0
# generation_gwh_2014         371
# generation_gwh_2015         396
# generation_gwh_2016         403
# generation_gwh_2017         408
# generation_gwh_2018         410
# generation_gwh_2019           0
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %%
# The columns "country" and "country_long" has only one data.
# so we will remove both the columns.

# %%
df=df.drop(columns=['country','country_long'])

# %%
df.head()
# Out:
#                        name   gppd_idnr  capacity_mw  latitude  longitude  \
# 0          ACME Solar Tower  WRI1020239          2.5   28.1839    73.2407
# 1       ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663    74.6090
# 2  AES Saurashtra Windfarms  WRI1026669         39.2   21.9038    69.3732
# 3               AGARTALA GT  IND0000001        135.0   23.8712    91.3602
# 4              AKALTARA TPP  IND0000002       1800.0   21.9603    82.4091
#
#   primary_fuel other_fuel1 other_fuel2  other_fuel3  commissioning_year  ...  \
# 0        Solar         NaN         NaN          NaN              2011.0  ...
# 1         Coal         NaN         NaN          NaN                 NaN  ...
# 2         Wind         NaN         NaN          NaN                 NaN  ...
# 3          Gas         NaN         NaN          NaN              2004.0  ...
# 4         Coal         Oil         NaN          NaN              2015.0  ...
#
# ...

# %%
df.isnull().sum()
# Out:
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# There are no duplicated values present

# %%
df.isna().sum()
# Out:
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
# some columns have only null values, so we will remove them from our dataset first.

# %%
df=df.drop(columns=['estimated_generation_gwh','generation_gwh_2019','generation_gwh_2013','wepp_id','other_fuel3','other_fuel2'])

# %%
df.head()
# Out:
#                        name   gppd_idnr  capacity_mw  latitude  longitude  \
# 0          ACME Solar Tower  WRI1020239          2.5   28.1839    73.2407
# 1       ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663    74.6090
# 2  AES Saurashtra Windfarms  WRI1026669         39.2   21.9038    69.3732
# 3               AGARTALA GT  IND0000001        135.0   23.8712    91.3602
# 4              AKALTARA TPP  IND0000002       1800.0   21.9603    82.4091
#
#   primary_fuel other_fuel1  commissioning_year                 owner  \
# 0        Solar         NaN              2011.0           Solar Paces
# 1         Coal         NaN                 NaN  Ultratech Cement ltd
# 2         Wind         NaN                 NaN                   AES
# 3          Gas         NaN              2004.0                   NaN
# 4         Coal         Oil              2015.0                   NaN
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# ...

# %%
df['name'].value_counts()
# Out:
# ACME Solar Tower           1
# RAICHUR                    1
# PRYAGRAJ (BARA) TPP        1
# PULICHINTALA               1
# PUNE MILL                  1
#                           ..
# KADANA                     1
# KADRA                      1
# KAHALGAON                  1
# KAIGA                      1
# iEnergy Theni Wind Farm    1
# Name: name, Length: 907, dtype: int64

# %%
# column 'name' will not have any impact on the target variable, so we will remove them.

# %%
df=df.drop(columns=['name'])

# %%
df
# Out:
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0    WRI1020239          2.5   28.1839    73.2407        Solar         NaN
# 1    WRI1019881         98.0   24.7663    74.6090         Coal         NaN
# 2    WRI1026669         39.2   21.9038    69.3732         Wind         NaN
# 3    IND0000001        135.0   23.8712    91.3602          Gas         NaN
# 4    IND0000002       1800.0   21.9603    82.4091         Coal         Oil
# ..          ...          ...       ...        ...          ...         ...
# 902  IND0000513       1600.0   16.2949    77.3568         Coal         Oil
# 903  WRI1026222          3.0   12.8932    78.1654        Solar         NaN
# 904  WRI1026776         25.5   15.2758    75.5811         Wind         NaN
# 905  WRI1019901         80.0   24.3500    73.7477         Coal         NaN
# 906  WRI1026761         16.5    9.9344    77.4768         Wind         NaN
#
#      commissioning_year                                owner  \
# ...

# %%
df['gppd_idnr'].value_counts()
# Out:
# WRI1020239    1
# IND0000356    1
# IND0000346    1
# IND0000523    1
# WRI1019978    1
#              ..
# IND0000167    1
# IND0000168    1
# IND0000169    1
# IND0000170    1
# WRI1026761    1
# Name: gppd_idnr, Length: 907, dtype: int64

# %%
# column 'gppd_idnr' will not have any impact on the target variable, so we will remove it as well.

# %%
df['gppd_idnr'].value_counts().sum()
# Out:
# 907

# %%
df=df.drop(columns=['gppd_idnr'])

# %%
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0            2.5   28.1839    73.2407        Solar         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil
# ..           ...       ...        ...          ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil
# 903          3.0   12.8932    78.1654        Solar         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN
#
#      commissioning_year                                owner  \
# 0                2011.0                          Solar Paces
# 1                   NaN                 Ultratech Cement ltd
# ...

# %%
df.isnull().sum()
# Out:
# capacity_mw                 0
# latitude                   46
# longitude                  46
# primary_fuel                0
# other_fuel1               709
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %%
df['latitude'].value_counts()
# Out:
# 19.0004    3
# 24.1917    3
# 24.8747    2
# 13.2450    2
# 11.5336    2
#           ..
# 22.7554    1
# 27.1598    1
# 17.2970    1
# 20.8772    1
# 9.9344     1
# Name: latitude, Length: 836, dtype: int64

# %%
df['latitude'].nunique()
# Out:
# 836

# %%
# Let's impute values by using mean method.

# %%
df['latitude']=df['latitude'].fillna(df['latitude'].mean())

# %%
df.isnull().sum()
# Out:
# capacity_mw                 0
# latitude                    0
# longitude                  46
# primary_fuel                0
# other_fuel1               709
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %%
df['longitude']=df['longitude'].fillna(df['longitude'].mean())

# %%
df.isnull().sum()
# Out:
# capacity_mw                 0
# latitude                    0
# longitude                   0
# primary_fuel                0
# other_fuel1               709
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %%
df['other_fuel1'].value_counts()
# Out:
# Oil             195
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %%
df['owner'].value_counts().sum()
# Out:
# 342

# %%
# the missing values in 'other_fuel1' and 'owner' are very high compared with the  overall data, so we will remove these two columns as well.

# %%
df=df.drop(columns=['other_fuel1','owner'])

# %%
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# 1           98.0   24.7663    74.6090         Coal                 NaN
# 2           39.2   21.9038    69.3732         Wind                 NaN
# 3          135.0   23.8712    91.3602          Gas              2004.0
# 4         1800.0   21.9603    82.4091         Coal              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar                 NaN
# 904         25.5   15.2758    75.5811         Wind                 NaN
# 905         80.0   24.3500    73.7477         Coal                 NaN
# 906         16.5    9.9344    77.4768         Wind                 NaN
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      527 non-null    float64
#  5   source                  907 non-null    object
#  6   url                     907 non-null    object
#  7   geolocation_source      888 non-null    object
#  8   year_of_capacity_data   519 non-null    float64
#  9   generation_gwh_2014     398 non-null    float64
#  10  generation_gwh_2015     422 non-null    float64
#  11  generation_gwh_2016     434 non-null    float64
#  12  generation_gwh_2017     440 non-null    float64
#  13  generation_gwh_2018     448 non-null    float64
# ...

# %%
df['commissioning_year'].isna().sum()
# Out:
# 380

# %%
df['commissioning_year'].value_counts().sum()
# Out:
# 527

# %%
# we will use the median method to deal with the null values in column 'commissioning_year'

# %%
df['commissioning_year']=df['commissioning_year'].fillna(df['commissioning_year'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   url                     907 non-null    object
#  7   geolocation_source      888 non-null    object
#  8   year_of_capacity_data   519 non-null    float64
#  9   generation_gwh_2014     398 non-null    float64
#  10  generation_gwh_2015     422 non-null    float64
#  11  generation_gwh_2016     434 non-null    float64
#  12  generation_gwh_2017     440 non-null    float64
#  13  generation_gwh_2018     448 non-null    float64
# ...

# %%
df.tail()
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar              2001.0
# 904         25.5   15.2758    75.5811         Wind              2001.0
# 905         80.0   24.3500    73.7477         Coal              2001.0
# 906         16.5    9.9344    77.4768         Wind              2001.0
#
#                                   source  \
# 902        Central Electricity Authority
# 903  Karnataka Power Corporation Limited
# 904                                  CDM
# 905                   Hindustan Zinc ltd
# 906                                  CDM
#
#                                                    url geolocation_source  \
# 902                             http://www.cea.nic.in/                WRI
# 903                          http://karnatakapower.com     Industry About
# ...

# %%
# column 'url' will not have an impact on target variables, so we will remove it.

# %%
df=df.drop(columns=['url'])

# %%
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# 1           98.0   24.7663    74.6090         Coal              2001.0
# 2           39.2   21.9038    69.3732         Wind              2001.0
# 3          135.0   23.8712    91.3602          Gas              2004.0
# 4         1800.0   21.9603    82.4091         Coal              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar              2001.0
# 904         25.5   15.2758    75.5811         Wind              2001.0
# 905         80.0   24.3500    73.7477         Coal              2001.0
# 906         16.5    9.9344    77.4768         Wind              2001.0
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   geolocation_source      888 non-null    object
#  7   year_of_capacity_data   519 non-null    float64
#  8   generation_gwh_2014     398 non-null    float64
#  9   generation_gwh_2015     422 non-null    float64
#  10  generation_gwh_2016     434 non-null    float64
#  11  generation_gwh_2017     440 non-null    float64
#  12  generation_gwh_2018     448 non-null    float64
#  13  generation_data_source  449 non-null    object
# ...

# %%
df['geolocation_source'].value_counts()
# Out:
# WRI                                     765
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
# we will use mode method to deal with the null values in the column 'geolocation_source' as it contains categorical data.

# %%
df['geolocation_source']=df['geolocation_source'].fillna(df['geolocation_source'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   geolocation_source      907 non-null    object
#  7   year_of_capacity_data   519 non-null    float64
#  8   generation_gwh_2014     398 non-null    float64
#  9   generation_gwh_2015     422 non-null    float64
#  10  generation_gwh_2016     434 non-null    float64
#  11  generation_gwh_2017     440 non-null    float64
#  12  generation_gwh_2018     448 non-null    float64
#  13  generation_data_source  449 non-null    object
# ...

# %%
df['year_of_capacity_data'].value_counts()
# Out:
# 2019.0    519
# Name: year_of_capacity_data, dtype: int64

# %%
# The column 'year_of_capacity_data' has only one '2019' in the whole dataset, so we will remove it.

# %%
df=df.drop(columns=['year_of_capacity_data'])

# %%
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# 1           98.0   24.7663    74.6090         Coal              2001.0
# 2           39.2   21.9038    69.3732         Wind              2001.0
# 3          135.0   23.8712    91.3602          Gas              2004.0
# 4         1800.0   21.9603    82.4091         Coal              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar              2001.0
# 904         25.5   15.2758    75.5811         Wind              2001.0
# 905         80.0   24.3500    73.7477         Coal              2001.0
# 906         16.5    9.9344    77.4768         Wind              2001.0
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   geolocation_source      907 non-null    object
#  7   generation_gwh_2014     398 non-null    float64
#  8   generation_gwh_2015     422 non-null    float64
#  9   generation_gwh_2016     434 non-null    float64
#  10  generation_gwh_2017     440 non-null    float64
#  11  generation_gwh_2018     448 non-null    float64
#  12  generation_data_source  449 non-null    object
# dtypes: float64(9), object(4)
# memory usage: 92.2+ KB

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0          2.5   28.1839    73.2407        Solar              2011.0
# 1         98.0   24.7663    74.6090         Coal              2001.0
# 2         39.2   21.9038    69.3732         Wind              2001.0
# 3        135.0   23.8712    91.3602          Gas              2004.0
# 4       1800.0   21.9603    82.4091         Coal              2015.0
#
#                                  source                    geolocation_source  \
# 0  National Renewable Energy Laboratory  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd                                   WRI
# 2                                   CDM                                   WRI
# 3         Central Electricity Authority                                   WRI
# 4         Central Electricity Authority                                   WRI
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# ...

# %%
df['generation_gwh_2014'].value_counts()
# Out:
# 0.000000       28
# 617.789264      1
# 359.139800      1
# 7368.390000     1
# 9983.018000     1
#                ..
# 4436.700000     1
# 1154.342000     1
# 451.053400      1
# 3239.142900     1
# 3194.359820     1
# Name: generation_gwh_2014, Length: 371, dtype: int64

# %%
df['generation_gwh_2014'].value_counts().sum()
# Out:
# 398

# %%
# we will use mean method to deal with the null values in the column 'generation_gwh_2014'.

# %%
df['generation_gwh_2014']=df['generation_gwh_2014'].fillna(df['generation_gwh_2014'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   geolocation_source      907 non-null    object
#  7   generation_gwh_2014     907 non-null    float64
#  8   generation_gwh_2015     422 non-null    float64
#  9   generation_gwh_2016     434 non-null    float64
#  10  generation_gwh_2017     440 non-null    float64
#  11  generation_gwh_2018     448 non-null    float64
#  12  generation_data_source  449 non-null    object
# dtypes: float64(9), object(4)
# memory usage: 92.2+ KB

# %%
# now let's deal with null values of column 'generation_gwh_2015' using mean method as well.

# %%
df['generation_gwh_2015']=df['generation_gwh_2015'].fillna(df['generation_gwh_2015'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   geolocation_source      907 non-null    object
#  7   generation_gwh_2014     907 non-null    float64
#  8   generation_gwh_2015     907 non-null    float64
#  9   generation_gwh_2016     434 non-null    float64
#  10  generation_gwh_2017     440 non-null    float64
#  11  generation_gwh_2018     448 non-null    float64
#  12  generation_data_source  449 non-null    object
# dtypes: float64(9), object(4)
# memory usage: 92.2+ KB

# %%
# let's fix null values in 'generation_gwh_2016' column using mean method.

# %%
df['generation_gwh_2016']=df['generation_gwh_2016'].fillna(df['generation_gwh_2016'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   geolocation_source      907 non-null    object
#  7   generation_gwh_2014     907 non-null    float64
#  8   generation_gwh_2015     907 non-null    float64
#  9   generation_gwh_2016     907 non-null    float64
#  10  generation_gwh_2017     440 non-null    float64
#  11  generation_gwh_2018     448 non-null    float64
#  12  generation_data_source  449 non-null    object
# dtypes: float64(9), object(4)
# memory usage: 92.2+ KB

# %%
# let's fix null values in 'generation_gwh_2017' column using mean method.

# %%
df['generation_gwh_2017']=df['generation_gwh_2017'].fillna(df['generation_gwh_2017'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   geolocation_source      907 non-null    object
#  7   generation_gwh_2014     907 non-null    float64
#  8   generation_gwh_2015     907 non-null    float64
#  9   generation_gwh_2016     907 non-null    float64
#  10  generation_gwh_2017     907 non-null    float64
#  11  generation_gwh_2018     448 non-null    float64
#  12  generation_data_source  449 non-null    object
# dtypes: float64(9), object(4)
# memory usage: 92.2+ KB

# %%
# let's fix null values in 'generation_gwh_2018' column using mean method.

# %%
df['generation_gwh_2018']=df['generation_gwh_2018'].fillna(df['generation_gwh_2018'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   capacity_mw             907 non-null    float64
#  1   latitude                907 non-null    float64
#  2   longitude               907 non-null    float64
#  3   primary_fuel            907 non-null    object
#  4   commissioning_year      907 non-null    float64
#  5   source                  907 non-null    object
#  6   geolocation_source      907 non-null    object
#  7   generation_gwh_2014     907 non-null    float64
#  8   generation_gwh_2015     907 non-null    float64
#  9   generation_gwh_2016     907 non-null    float64
#  10  generation_gwh_2017     907 non-null    float64
#  11  generation_gwh_2018     907 non-null    float64
#  12  generation_data_source  449 non-null    object
# dtypes: float64(9), object(4)
# memory usage: 92.2+ KB

# %%
df['generation_data_source']
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3      Central Electricity Authority
# 4      Central Electricity Authority
#                    ...
# 902    Central Electricity Authority
# 903                              NaN
# 904                              NaN
# 905                              NaN
# 906                              NaN
# Name: generation_data_source, Length: 907, dtype: object

# %%
df['generation_data_source'].value_counts()
# Out:
# Central Electricity Authority    449
# Name: generation_data_source, dtype: int64

# %%
# the column 'generation_data_source' has only one kind of data, so we will remove it.

# %%
df=df.drop(columns=['generation_data_source'])

# %%
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# 1           98.0   24.7663    74.6090         Coal              2001.0
# 2           39.2   21.9038    69.3732         Wind              2001.0
# 3          135.0   23.8712    91.3602          Gas              2004.0
# 4         1800.0   21.9603    82.4091         Coal              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar              2001.0
# 904         25.5   15.2758    75.5811         Wind              2001.0
# 905         80.0   24.3500    73.7477         Coal              2001.0
# 906         16.5    9.9344    77.4768         Wind              2001.0
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# ...

# %%
# now let's visualise the data.

# %% [markdown]
# # Data Visualisation.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   capacity_mw          907 non-null    float64
#  1   latitude             907 non-null    float64
#  2   longitude            907 non-null    float64
#  3   primary_fuel         907 non-null    object
#  4   commissioning_year   907 non-null    float64
#  5   source               907 non-null    object
#  6   geolocation_source   907 non-null    object
#  7   generation_gwh_2014  907 non-null    float64
#  8   generation_gwh_2015  907 non-null    float64
#  9   generation_gwh_2016  907 non-null    float64
#  10  generation_gwh_2017  907 non-null    float64
#  11  generation_gwh_2018  907 non-null    float64
# dtypes: float64(9), object(3)
# memory usage: 85.2+ KB

# %%
df['primary_fuel'].value_counts().plot.pie()
plt.show()

# %%
sns.countplot('primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %%
# Coal is bieng used as primary fuel the  most.

# %%
df['source'].value_counts()
# Out:
# Central Electricity Authority                                  519
# CDM                                                            124
# Lancosola                                                       10
# National Renewable Energy Laboratory                             8
# National Thermal Power Corporation (NTPC)                        6
#                                                               ...
# Harsha Engineers Limited                                         1
# Godawari Energy ltd                                              1
# Sunkon Energy Private Limited                                    1
# West Bengal Energy Development Corporation Limited (WBEDCL)      1
# Yashwantrao Krishna ssk                                          1
# Name: source, Length: 191, dtype: int64

# %%
df['source'].value_counts().sum()
# Out:
# 907

# %%
df['geolocation_source'].value_counts()
# Out:
# WRI                                     784
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
sns.countplot('geolocation_source',data=df)
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='count'>

# %%
# WRI is being used the most.

# %%
sns.barplot('primary_fuel',y='capacity_mw',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='capacity_mw'>

# %%
n_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        n_col.append(i)
print(n_col)
# Out:
# ['capacity_mw', 'latitude', 'longitude', 'commissioning_year', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018']

# %%
plt.figure(figsize=(13,13))
pltn=1
for col in n_col:
    if pltn<=9:
        ax=plt.subplot(3,3,pltn)
        sns.distplot(df[col],color='c')
        plt.xlabel(col,fontsize=15)
    pltn+=1
plt.tight_layout()

# %%
# almost every column has some skewness.

# %%
# Let's encode the data first.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['primary_fuel']=le.fit_transform(df['primary_fuel'])

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0          2.5   28.1839    73.2407             6              2011.0
# 1         98.0   24.7663    74.6090             1              2001.0
# 2         39.2   21.9038    69.3732             7              2001.0
# 3        135.0   23.8712    91.3602             2              2004.0
# 4       1800.0   21.9603    82.4091             1              2015.0
#
#                                  source                    geolocation_source  \
# 0  National Renewable Energy Laboratory  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd                                   WRI
# 2                                   CDM                                   WRI
# 3         Central Electricity Authority                                   WRI
# 4         Central Electricity Authority                                   WRI
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# ...

# %%
df['primary_fuel'].value_counts()
# Out:
# 1    258
# 3    251
# 6    127
# 7    123
# 2     69
# 0     50
# 5     20
# 4      9
# Name: primary_fuel, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
df['source']=le.fit_transform(df['source'])
df['geolocation_source']=le.fit_transform(df['geolocation_source'])

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude  primary_fuel  commissioning_year  source  \
# 0          2.5   28.1839    73.2407             6              2011.0     109
# 1         98.0   24.7663    74.6090             1              2001.0     174
# 2         39.2   21.9038    69.3732             7              2001.0      21
# 3        135.0   23.8712    91.3602             2              2004.0      22
# 4       1800.0   21.9603    82.4091             1              2015.0      22
#
#    geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0                   1          2431.823590          2428.226946
# 1                   2          2431.823590          2428.226946
# 2                   2          2431.823590          2428.226946
# 3                   2           617.789264           843.747000
# 4                   2          3035.550000          5916.370000
#
#    generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# ...

# %%
# now let's see the correlation between features and target variable as well.

# %%
df.corr()
# Out:
#                      capacity_mw  latitude  longitude  primary_fuel  \
# capacity_mw             1.000000  0.050984   0.195882     -0.380395
# latitude                0.050984  1.000000   0.036362     -0.010204
# longitude               0.195882  0.036362   1.000000     -0.347948
# primary_fuel           -0.380395 -0.010204  -0.347948      1.000000
# commissioning_year      0.211042  0.087937   0.029893     -0.054885
# source                 -0.242122  0.055927  -0.239333      0.053613
# geolocation_source      0.204865 -0.184275   0.252343     -0.483217
# generation_gwh_2014     0.694350  0.044321   0.011472     -0.124769
# generation_gwh_2015     0.711190  0.036398   0.018818     -0.124828
# generation_gwh_2016     0.742221  0.031256   0.039209     -0.131051
# generation_gwh_2017     0.757585  0.031212   0.039675     -0.132003
# generation_gwh_2018     0.773456  0.031326   0.037780     -0.136983
#
#                      commissioning_year        source  geolocation_source  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# the columns 'generation_gwh_2017' and 'generation_gwh_2018' are highly correlated with each other, so we will remove one them.
# We will drop the column which is less correlated with the target variable.

# %% [markdown]
# # primary fuel is our target variable at first.

# %%
ndf=df.copy()

# %%
ndf
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6              2011.0
# 1           98.0   24.7663    74.6090             1              2001.0
# 2           39.2   21.9038    69.3732             7              2001.0
# 3          135.0   23.8712    91.3602             2              2004.0
# 4         1800.0   21.9603    82.4091             1              2015.0
# ..           ...       ...        ...           ...                 ...
# 902       1600.0   16.2949    77.3568             1              2016.0
# 903          3.0   12.8932    78.1654             6              2001.0
# 904         25.5   15.2758    75.5811             7              2001.0
# 905         80.0   24.3500    73.7477             1              2001.0
# 906         16.5    9.9344    77.4768             7              2001.0
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# ...

# %%
ndf=ndf.drop(columns=['generation_gwh_2018'])

# %%
ndf
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6              2011.0
# 1           98.0   24.7663    74.6090             1              2001.0
# 2           39.2   21.9038    69.3732             7              2001.0
# 3          135.0   23.8712    91.3602             2              2004.0
# 4         1800.0   21.9603    82.4091             1              2015.0
# ..           ...       ...        ...           ...                 ...
# 902       1600.0   16.2949    77.3568             1              2016.0
# 903          3.0   12.8932    78.1654             6              2001.0
# 904         25.5   15.2758    75.5811             7              2001.0
# 905         80.0   24.3500    73.7477             1              2001.0
# 906         16.5    9.9344    77.4768             7              2001.0
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(ndf.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# the columns 'generation_gwh_2015' and 'generation_gwh_2016' are also highly correlated, so we will remove  one.
# now we can observve that columns 'generation_gwh_2016' and 'generation_gwh_2017' are highly correlated, so we will remove one of them.

# %%
ndf=ndf.drop(columns=['generation_gwh_2016'])
ndf=ndf.drop(columns=['generation_gwh_2017'])

# %%
ndf
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6              2011.0
# 1           98.0   24.7663    74.6090             1              2001.0
# 2           39.2   21.9038    69.3732             7              2001.0
# 3          135.0   23.8712    91.3602             2              2004.0
# 4         1800.0   21.9603    82.4091             1              2015.0
# ..           ...       ...        ...           ...                 ...
# 902       1600.0   16.2949    77.3568             1              2016.0
# 903          3.0   12.8932    78.1654             6              2001.0
# 904         25.5   15.2758    75.5811             7              2001.0
# 905         80.0   24.3500    73.7477             1              2001.0
# 906         16.5    9.9344    77.4768             7              2001.0
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(ndf.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,25),facecolor='Yellow')
pltno=1

for c in ndf:
    if pltno<=12:
        ax=plt.subplot(4,3,pltno)
        sns.distplot(df[c])
        plt.xlabel(c,fontsize=15)
        
    pltno+=1

# %%
# there is definitely soe skeewness present in almost every columns.

# %%
# Let's look for the outliers.

# %%
plt.figure(figsize=(20,10),facecolor='r')
pn=1
for c in ndf:
    if pn<=9:
        ax=plt.subplot(3,3,pn)
        sns.boxplot(ndf[c])
        plt.xlabel(c,fontsize=15)
    pn+=1

# %%
# there are outliers present, so let's fix them.

# %%
from scipy.stats import zscore
import numpy as np

z=np.abs(zscore(ndf))

z.shape
# Out:
# (907, 9)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 15,  15,  71,  80, 143, 143, 143, 147, 158, 179, 183, 191, 209,
#        209, 209, 219, 222, 244, 299, 308, 308, 308, 321, 323, 333, 340,
#        342, 345, 360, 363, 364, 364, 364, 371, 375, 416, 427, 444, 454,
#        478, 482, 484, 493, 493, 493, 494, 494, 494, 499, 519, 538, 541,
#        546, 573, 577, 583, 592, 601, 621, 638, 648, 648, 648, 657, 657,
#        657, 661, 669, 689, 695, 695, 695, 706, 709, 721, 721, 724, 724,
#        726, 726, 726, 728, 767, 786, 786, 786, 788, 807, 808, 808, 808,
#        818, 832, 847, 848, 870, 871, 879, 880, 880, 880, 895, 900],
#       dtype=int64), array([0, 8, 5, 5, 0, 7, 8, 0, 7, 2, 2, 5, 0, 7, 8, 4, 4, 2, 5, 0, 7, 8,
#        5, 2, 2, 2, 4, 5, 2, 0, 0, 7, 8, 4, 0, 2, 2, 4, 4, 4, 0, 4, 0, 7,
#        8, 0, 7, 8, 2, 2, 4, 4, 2, 4, 2, 4, 4, 4, 4, 2, 0, 7, 8, 0, 7, 8,
#        5, 5, 5, 0, 7, 8, 4, 4, 7, 8, 7, 8, 0, 7, 8, 4, 0, 0, 7, 8, 0, 4,
#        0, 7, 8, 2, 5, 2, 4, 5, 5, 5, 0, 7, 8, 5, 5], dtype=int64))

# %%
 df1=ndf[(z<3).all(axis=1)]
df1
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6              2011.0
# 1           98.0   24.7663    74.6090             1              2001.0
# 2           39.2   21.9038    69.3732             7              2001.0
# 3          135.0   23.8712    91.3602             2              2004.0
# 4         1800.0   21.9603    82.4091             1              2015.0
# ..           ...       ...        ...           ...                 ...
# 902       1600.0   16.2949    77.3568             1              2016.0
# 903          3.0   12.8932    78.1654             6              2001.0
# 904         25.5   15.2758    75.5811             7              2001.0
# 905         80.0   24.3500    73.7477             1              2001.0
# 906         16.5    9.9344    77.4768             7              2001.0
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015
# ...

# %%
df1.shape
# Out:
# (833, 9)

# %%
ndf.shape
# Out:
# (907, 9)

# %%
# data loss

(907-833)/907*100
# Out:
# 8.158765159867695

# %%
# 8.15% of data loss is acceptable.

# %%
# now let's seperate the features and label.

# %%
x=df1.drop(columns=['primary_fuel'])
y=df1['primary_fuel']

# %%
x
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  source  \
# 0            2.5   28.1839    73.2407              2011.0     109
# 1           98.0   24.7663    74.6090              2001.0     174
# 2           39.2   21.9038    69.3732              2001.0      21
# 3          135.0   23.8712    91.3602              2004.0      22
# 4         1800.0   21.9603    82.4091              2015.0      22
# ..           ...       ...        ...                 ...     ...
# 902       1600.0   16.2949    77.3568              2016.0      22
# 903          3.0   12.8932    78.1654              2001.0      77
# 904         25.5   15.2758    75.5811              2001.0      21
# 905         80.0   24.3500    73.7477              2001.0      59
# 906         16.5    9.9344    77.4768              2001.0      21
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015
# 0                     1          2431.823590          2428.226946
# ...

# %%
y
# Out:
# 0      6
# 1      1
# 2      7
# 3      2
# 4      1
#       ..
# 902    1
# 903    6
# 904    7
# 905    1
# 906    7
# Name: primary_fuel, Length: 833, dtype: int32

# %%
x.skew()
# Out:
# capacity_mw            1.950900
# latitude              -0.116170
# longitude              0.909304
# commissioning_year    -1.266675
# source                 1.782665
# geolocation_source    -2.102192
# generation_gwh_2014    1.523020
# generation_gwh_2015    1.388494
# dtype: float64

# %%
# let's deal with the skewness

# %%
s=['capacity_mw','longitude','commissioning_year','source','geolocation_source','generation_gwh_2014','generation_gwh_2015']

# %%
from sklearn.preprocessing import PowerTransformer
yj = PowerTransformer(method = 'yeo-johnson')

# %%
x[s] = yj.fit_transform(x[s].values)

# %%
x.skew()
# Out:
# capacity_mw            0.011203
# latitude              -0.116170
# longitude             -0.000259
# commissioning_year    -0.315826
# source                -0.178437
# geolocation_source    -2.074065
# generation_gwh_2014   -0.250359
# generation_gwh_2015   -0.313329
# dtype: float64

# %%
plt.figure(figsize=(20,25),facecolor='Yellow')
pltno=1

for c in x:
    if pltno<=9:
        ax=plt.subplot(3,3,pltno)
        sns.distplot(x[c])
        plt.xlabel(c,fontsize=15)
        
    pltno+=1

# %%
# now let's standardise the data.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaled_x = sc.fit_transform(x)
scaled_x
# Out:
# array([[-1.67085285,  1.16045784, -0.9297326 , ..., -2.27978618,
#          0.33287194,  0.36239937],
#        [ 0.20813459,  0.6019911 , -0.5136261 , ...,  0.4041996 ,
#          0.33287194,  0.36239937],
#        [-0.28711312,  0.13423272, -2.3513066 , ...,  0.4041996 ,
#          0.33287194,  0.36239937],
#        ...,
#        [-0.51891997, -0.9488424 , -0.24109599, ...,  0.4041996 ,
#          0.33287194,  0.36239937],
#        [ 0.09857924,  0.53396392, -0.77089201, ...,  0.4041996 ,
#          0.33287194,  0.36239937],
#        [-0.7515245 , -1.82167545,  0.24119071, ...,  0.4041996 ,
#          0.33287194,  0.36239937]])

# %%
xx=pd.DataFrame(scaled_x,columns=x.columns)

# %%
xx
# Out:
#      capacity_mw  latitude  longitude  commissioning_year    source  \
# 0      -1.670853  1.160458  -0.929733            1.148978  1.613712
# 1       0.208135  0.601991  -0.513626            0.004001  2.087889
# 2      -0.287113  0.134233  -2.351307            0.004001 -0.468791
# 3       0.380661  0.455724   2.444424            0.320411 -0.400650
# 4       1.747194  0.143465   1.246947            1.685448 -0.400650
# ..           ...       ...        ...                 ...       ...
# 828     1.686341 -0.782312   0.212451            1.827386 -0.400650
# 829    -1.593530 -1.338181   0.401748            0.004001  1.229535
# 830    -0.518920 -0.948842  -0.241096            0.004001 -0.468791
# 831     0.098579  0.533964  -0.770892            0.004001  0.915820
# 832    -0.751524 -1.821675   0.241191            0.004001 -0.468791
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015
# 0             -2.279786             0.332872             0.362399
# ...

# %%
# now we will check the vif values

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['Vif values']=[variance_inflation_factor(xx.values,i)
                    for i in range(len(xx.columns))]
vif["features"]=xx.columns

# %%
vif
# Out:
#    Vif values             features
# 0    1.529361          capacity_mw
# 1    1.082269             latitude
# 2    1.205136            longitude
# 3    1.103153   commissioning_year
# 4    1.247030               source
# 5    1.572517   geolocation_source
# 6    4.011334  generation_gwh_2014
# 7    4.047673  generation_gwh_2015

# %%
# The VIF values of all the features are  under 10..

# %%
# now we will build the models.

# %%
y
# Out:
# 0      6
# 1      1
# 2      7
# 3      2
# 4      1
#       ..
# 902    1
# 903    6
# 904    7
# 905    1
# 906    7
# Name: primary_fuel, Length: 833, dtype: int32

# %%
# our target variable is imbalanced, so we will balance it out first.

# %%
from imblearn.over_sampling import SMOTE
smt= SMOTE(random_state=33)
train_x,train_y=smt.fit_resample(xx,y)
train_y.value_counts()
# Out:
# 6    231
# 1    231
# 7    231
# 2    231
# 3    231
# 0    231
# 5    231
# 4    231
# Name: primary_fuel, dtype: int64

# %%
y
# Out:
# 0      6
# 1      1
# 2      7
# 3      2
# 4      1
#       ..
# 902    1
# 903    6
# 904    7
# 905    1
# 906    7
# Name: primary_fuel, Length: 833, dtype: int32

# %%
df_new=pd.DataFrame(data=train_x)
df_new['primary_fuel']=train_y
ndf=df_new
ndf
# Out:
#       capacity_mw  latitude  longitude  commissioning_year    source  \
# 0       -1.670853  1.160458  -0.929733            1.148978  1.613712
# 1        0.208135  0.601991  -0.513626            0.004001  2.087889
# 2       -0.287113  0.134233  -2.351307            0.004001 -0.468791
# 3        0.380661  0.455724   2.444424            0.320411 -0.400650
# 4        1.747194  0.143465   1.246947            1.685448 -0.400650
# ...           ...       ...        ...                 ...       ...
# 1843    -0.460627  0.018885   0.238353            0.004001 -0.468791
# 1844    -0.019535 -0.599855  -0.720204            0.004001 -0.468791
# 1845    -0.542548 -0.994134  -0.207589            0.004001 -0.468791
# 1846    -0.276666 -0.945671  -0.223137            0.004001 -0.468791
# 1847    -0.517123 -0.939630  -0.239776            0.004001 -0.468791
#
#       geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0              -2.279786             0.332872             0.362399
# ...

# %%
x=ndf.drop(columns=['primary_fuel'])
y=ndf['primary_fuel']

# %%
x
# Out:
#       capacity_mw  latitude  longitude  commissioning_year    source  \
# 0       -1.670853  1.160458  -0.929733            1.148978  1.613712
# 1        0.208135  0.601991  -0.513626            0.004001  2.087889
# 2       -0.287113  0.134233  -2.351307            0.004001 -0.468791
# 3        0.380661  0.455724   2.444424            0.320411 -0.400650
# 4        1.747194  0.143465   1.246947            1.685448 -0.400650
# ...           ...       ...        ...                 ...       ...
# 1843    -0.460627  0.018885   0.238353            0.004001 -0.468791
# 1844    -0.019535 -0.599855  -0.720204            0.004001 -0.468791
# 1845    -0.542548 -0.994134  -0.207589            0.004001 -0.468791
# 1846    -0.276666 -0.945671  -0.223137            0.004001 -0.468791
# 1847    -0.517123 -0.939630  -0.239776            0.004001 -0.468791
#
#       geolocation_source  generation_gwh_2014  generation_gwh_2015
# 0              -2.279786             0.332872             0.362399
# ...

# %%
y
# Out:
# 0       6
# 1       1
# 2       7
# 3       2
# 4       1
#        ..
# 1843    7
# 1844    7
# 1845    7
# 1846    7
# 1847    7
# Name: primary_fuel, Length: 1848, dtype: int32

# %%
y.value_counts()
# Out:
# 6    231
# 1    231
# 7    231
# 2    231
# 3    231
# 0    231
# 5    231
# 4    231
# Name: primary_fuel, dtype: int64

# %%
# classification model will be build for this problem.

# %% [markdown]
# # Model Building.

# %%
#importing necessary libraries for model building

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
maxAccu=0
maxRS=0
lg=LogisticRegression()
for i in range(20,40):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.25)
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best Accuracy score is', maxAccu , 'on random state', maxRS)
# Out:
# Best Accuracy score is 0.7510822510822511 on random state 33

# %%
# thee model gives best accuracy at random state 33

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=33,test_size=.25)

# %% [markdown]
# # Logistic Regression

# %%
lr=LogisticRegression()
lr.fit(xtrain,ytrain)
lpred=lr.predict(xtest)
print(accuracy_score(ytest,lpred))
print(confusion_matrix(ytest,lpred))
print(classification_report(ytest,lpred))
# Out:
# 0.7510822510822511
# [[54  1  0  0  0  1  0  3]
#  [ 4 28  9  4  9  4  0  2]
#  [ 1  7 25  6  0 12  0  1]
#  [ 0  7  3 24  1  6  0  6]
#  [ 0  3  0  6 55  0  0  0]
#  [ 1  2  0  0  0 46  0  5]
#  [ 0  2  0  0  0  0 62  1]
#  [ 0  0  0  8  0  0  0 53]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91        59
#            1       0.56      0.47      0.51        60
#            2       0.68      0.48      0.56        52
#            3       0.50      0.51      0.51        47
#            4       0.85      0.86      0.85        64
#            5       0.67      0.85      0.75        54
#            6       1.00      0.95      0.98        65
#            7       0.75      0.87      0.80        61
#
#     accuracy                           0.75       462
#    macro avg       0.74      0.74      0.73       462
# weighted avg       0.75      0.75      0.75       462

# %%
# 75.10% accuracy

# %% [markdown]
# # RandomForest Classifier

# %%
rc=RandomForestClassifier()
rc.fit(xtrain,ytrain)
cpred=rc.predict(xtest)
print(accuracy_score(ytest,cpred))
print(confusion_matrix(ytest,cpred))
print(classification_report(ytest,cpred))
# Out:
# 0.935064935064935
# [[58  0  0  0  0  1  0  0]
#  [ 5 46  4  2  1  2  0  0]
#  [ 0  2 44  0  1  5  0  0]
#  [ 0  1  2 42  0  2  0  0]
#  [ 0  0  0  0 64  0  0  0]
#  [ 0  0  1  1  0 52  0  0]
#  [ 0  0  0  0  0  0 65  0]
#  [ 0  0  0  0  0  0  0 61]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95        59
#            1       0.94      0.77      0.84        60
#            2       0.86      0.85      0.85        52
#            3       0.93      0.89      0.91        47
#            4       0.97      1.00      0.98        64
#            5       0.84      0.96      0.90        54
#            6       1.00      1.00      1.00        65
#            7       1.00      1.00      1.00        61
#
#     accuracy                           0.94       462
#    macro avg       0.93      0.93      0.93       462
# weighted avg       0.94      0.94      0.93       462

# %%
# 93.50% accuracy.

# %% [markdown]
# # SVC

# %%
svc=SVC()
svc.fit(xtrain,ytrain)
spred=svc.predict(xtest)
print(accuracy_score(ytest,spred))
print(confusion_matrix(ytest,spred))
print(classification_report(ytest,spred))
# Out:
# 0.8982683982683982
# [[59  0  0  0  0  0  0  0]
#  [ 5 43  3  3  2  0  0  4]
#  [ 0  3 39  0  1  9  0  0]
#  [ 0  3  3 35  0  2  0  4]
#  [ 0  0  0  0 64  0  0  0]
#  [ 0  2  0  0  0 49  0  3]
#  [ 0  0  0  0  0  0 65  0]
#  [ 0  0  0  0  0  0  0 61]]
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        59
#            1       0.84      0.72      0.77        60
#            2       0.87      0.75      0.80        52
#            3       0.92      0.74      0.82        47
#            4       0.96      1.00      0.98        64
#            5       0.82      0.91      0.86        54
#            6       1.00      1.00      1.00        65
#            7       0.85      1.00      0.92        61
#
#     accuracy                           0.90       462
#    macro avg       0.90      0.89      0.89       462
# weighted avg       0.90      0.90      0.90       462

# %%
# 89.82% accuracy.

# %% [markdown]
# # DecisionTree Classifier

# %%
dt=DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
dpred=dt.predict(xtest)
print(accuracy_score(ytest,dpred))
print(confusion_matrix(ytest,dpred))
print(classification_report(ytest,dpred))
# Out:
# 0.8917748917748918
# [[56  1  0  0  0  2  0  0]
#  [ 5 40  4  8  1  2  0  0]
#  [ 0  7 41  1  0  3  0  0]
#  [ 0  2  4 40  0  1  0  0]
#  [ 0  2  1  1 60  0  0  0]
#  [ 0  2  1  2  0 49  0  0]
#  [ 0  0  0  0  0  0 65  0]
#  [ 0  0  0  0  0  0  0 61]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93        59
#            1       0.74      0.67      0.70        60
#            2       0.80      0.79      0.80        52
#            3       0.77      0.85      0.81        47
#            4       0.98      0.94      0.96        64
#            5       0.86      0.91      0.88        54
#            6       1.00      1.00      1.00        65
#            7       1.00      1.00      1.00        61
#
#     accuracy                           0.89       462
#    macro avg       0.88      0.89      0.89       462
# weighted avg       0.89      0.89      0.89       462

# %%
# 89.17% accuracy.

# %% [markdown]
# # KNeighbors Classifier

# %%
k=KNeighborsClassifier()
k.fit(xtrain,ytrain)
kpred=k.predict(xtest)
print(accuracy_score(ytest,kpred))
print(confusion_matrix(ytest,kpred))
print(classification_report(ytest,kpred))
# Out:
# 0.8896103896103896
# [[58  1  0  0  0  0  0  0]
#  [ 6 37  6  4  5  0  0  2]
#  [ 0  3 45  0  0  4  0  0]
#  [ 0  5  4 31  0  4  0  3]
#  [ 0  0  0  0 64  0  0  0]
#  [ 1  0  0  1  0 51  0  1]
#  [ 0  0  0  0  0  0 65  0]
#  [ 0  1  0  0  0  0  0 60]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94        59
#            1       0.79      0.62      0.69        60
#            2       0.82      0.87      0.84        52
#            3       0.86      0.66      0.75        47
#            4       0.93      1.00      0.96        64
#            5       0.86      0.94      0.90        54
#            6       1.00      1.00      1.00        65
#            7       0.91      0.98      0.94        61
#
#     accuracy                           0.89       462
#    macro avg       0.88      0.88      0.88       462
# weighted avg       0.89      0.89      0.88       462

# %%
# 88.96% accuracy

# %% [markdown]
# # CrossValidation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
#for logistic regression

ls=cross_val_score(lr,x,y)
print(ls)
print(ls.mean())
# Out:
# [0.74054054 0.74324324 0.74054054 0.70731707 0.71273713]
# 0.7288757049732658

# %%
# for random forest classifier

rs=cross_val_score(rc,x,y)
print(rs)
print(rs.mean())
# Out:
# [0.92162162 0.93243243 0.92702703 0.92140921 0.92682927]
# 0.9258639126931811

# %%
# for svc

ss=cross_val_score(svc,x,y)
print(ss)
print(ss.mean())
# Out:
# [0.84324324 0.85405405 0.85135135 0.86720867 0.83468835]
# 0.8501091335237676

# %%
# for decisiontree classifier

ds=cross_val_score(dt,x,y)
print(ds)
print(ds.mean())
# Out:
# [0.84324324 0.8972973  0.90540541 0.88888889 0.87262873]
# 0.8814927122244194

# %%
# for kneighbors classifier

ks=cross_val_score(k,x,y)
print(ks)
print(ks.mean())
# Out:
# [0.88918919 0.86216216 0.87837838 0.87804878 0.84823848]
# 0.8712033985204716

# %%
# as per the observation, RandomForest classifier is our best model
# so hyperparameter tuning will be done on that model

# %% [markdown]
# # HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'max_features':['auto','sqrt','log2'],
      'max_depth':[5,10,15,20,25],
      'criterion':['gini','entropy']}

gcs=GridSearchCV(rc,param,cv=7,scoring='accuracy')
gcs.fit(xtrain,ytrain)
gcs.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt'}

# %%
fmodel=RandomForestClassifier(max_features='sqrt',criterion='gini',max_depth=15)

# %%
fmodel.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(max_depth=15, max_features='sqrt')

# %%
pred=fmodel.predict(xtest)
acc=accuracy_score(ytest,pred)
print(acc*100)
# Out:
# 93.29004329004329

# %%
#  the randomforest classifier gives the accuracy of 93.29%

# %%
# let's save the model

# %%
import joblib
joblib.dump(fmodel,'global_powerplant_primaryfuel')
# Out:
# ['global_powerplant_primaryfuel']

# %%
#load the model

# %%
m = joblib.load("global_powerplant_primaryfuel")
print(m.predict(xtest))
# Out:
# [1 6 5 6 3 4 5 1 6 2 1 1 4 2 3 6 4 1 1 2 2 7 5 2 0 0 6 3 0 7 5 6 5 4 2 1 0
#  4 7 7 4 4 2 3 0 7 1 4 1 1 7 4 0 4 0 7 6 4 0 4 2 6 4 5 0 3 1 0 3 1 4 3 0 2
#  3 2 4 0 4 5 2 4 6 6 0 0 1 3 3 6 2 5 5 7 4 4 7 6 2 6 5 0 2 1 5 7 6 6 3 4 7
#  7 1 6 3 1 0 0 5 0 4 5 6 6 3 5 3 6 0 3 5 2 0 3 6 1 7 4 2 2 4 0 6 1 4 2 1 0
#  7 2 4 6 5 6 1 7 5 5 3 7 5 3 2 5 3 7 3 2 2 0 4 3 1 1 6 3 5 5 3 3 4 7 6 5 7
#  2 4 7 1 5 6 3 7 6 4 7 4 0 7 4 5 6 4 3 6 0 6 6 5 4 1 4 6 7 1 5 6 2 2 6 0 7
#  2 7 3 5 3 4 4 3 7 2 6 3 0 7 7 1 0 0 0 1 2 6 4 6 0 4 0 5 3 1 4 6 5 3 1 5 6
#  7 5 4 7 5 6 5 4 6 5 0 2 0 1 0 5 7 5 4 1 6 0 5 0 2 0 3 2 4 1 5 7 1 0 0 7 6
#  1 6 1 4 7 6 0 2 2 2 7 1 3 3 5 0 5 7 2 1 4 1 5 4 2 3 4 5 1 2 1 7 7 5 2 4 5
#  7 0 6 2 5 3 4 4 4 7 7 2 0 3 5 7 6 3 2 5 6 3 4 1 6 0 4 6 5 7 5 0 3 1 2 1 6
#  4 3 3 2 5 4 7 7 7 0 5 7 2 2 6 1 0 6 7 5 4 1 0 6 1 0 6 6 6 0 4 5 2 0 0 2 0
#  1 0 6 6 5 7 0 4 3 0 6 7 5 2 0 5 2 7 5 4 2 7 3 6 7 3 4 0 1 0 1 6 0 0 6 5 4
#  2 7 3 7 7 3 5 6 7 0 4 7 7 4 4 7 4 6]

# %%
d=pd.DataFrame({'predicted values':pred,'actual values':ytest})

# %%
d
# Out:
#       predicted values  actual values
# 4                    1              1
# 1669                 6              6
# 1433                 5              5
# 1677                 6              6
# 507                  3              3
# ...                ...            ...
# 1201                 4              4
# 1276                 4              4
# 196                  7              7
# 1375                 4              4
# 1716                 6              6
#
# [462 rows x 2 columns]

# %% [markdown]
# # Now taking 'capacity_mw' as target variable.

# %%
df
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6              2011.0
# 1           98.0   24.7663    74.6090             1              2001.0
# 2           39.2   21.9038    69.3732             7              2001.0
# 3          135.0   23.8712    91.3602             2              2004.0
# 4         1800.0   21.9603    82.4091             1              2015.0
# ..           ...       ...        ...           ...                 ...
# 902       1600.0   16.2949    77.3568             1              2016.0
# 903          3.0   12.8932    78.1654             6              2001.0
# 904         25.5   15.2758    75.5811             7              2001.0
# 905         80.0   24.3500    73.7477             1              2001.0
# 906         16.5    9.9344    77.4768             7              2001.0
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# capacity_mw            3.123576
# latitude              -0.149698
# longitude              1.141881
# primary_fuel           0.472251
# commissioning_year    -1.719575
# source                 1.827373
# geolocation_source    -2.159841
# generation_gwh_2014    5.035446
# generation_gwh_2015    5.364134
# generation_gwh_2016    5.068427
# generation_gwh_2017    5.110952
# generation_gwh_2018    4.937907
# dtype: float64

# %%
plt.figure(figsize=(20,10),facecolor='w')
pn=1
for c in df:
    if pn<=12:
        ax=plt.subplot(3,4,pn)
        sns.boxplot(df[c])
        plt.xlabel(c,fontsize=15)
    pn+=1

# %%
from scipy.stats import zscore
import numpy as np

z=np.abs(zscore(df))

z.shape
# Out:
# (907, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 15,  15,  15,  15,  15,  71,  80, 143, 143, 143, 143, 143, 143,
#        147, 158, 179, 183, 191, 209, 209, 209, 209, 209, 209, 219, 222,
#        244, 299, 308, 308, 308, 308, 308, 308, 321, 323, 333, 340, 342,
#        345, 360, 363, 364, 364, 364, 364, 364, 364, 371, 375, 416, 427,
#        444, 454, 478, 482, 484, 493, 493, 493, 493, 493, 493, 494, 494,
#        494, 494, 494, 494, 499, 519, 538, 541, 546, 573, 577, 583, 592,
#        601, 621, 638, 648, 648, 648, 648, 648, 648, 657, 657, 657, 657,
#        657, 657, 661, 669, 689, 695, 695, 695, 695, 695, 695, 706, 709,
#        721, 721, 721, 721, 724, 724, 724, 724, 724, 726, 726, 726, 726,
#        726, 726, 728, 767, 786, 786, 786, 786, 786, 786, 788, 807, 808,
#        808, 808, 808, 808, 808, 818, 832, 847, 848, 870, 871, 879, 880,
#        880, 880, 880, 880, 880, 895, 900], dtype=int64), array([ 0,  8,  9, 10, 11,  5,  5,  0,  7,  8,  9, 10, 11,  0,  7,  2,  2,
# ...

# %%
 df2=df[(z<3).all(axis=1)]
df2
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6              2011.0
# 1           98.0   24.7663    74.6090             1              2001.0
# 2           39.2   21.9038    69.3732             7              2001.0
# 3          135.0   23.8712    91.3602             2              2004.0
# 4         1800.0   21.9603    82.4091             1              2015.0
# ..           ...       ...        ...           ...                 ...
# 902       1600.0   16.2949    77.3568             1              2016.0
# 903          3.0   12.8932    78.1654             6              2001.0
# 904         25.5   15.2758    75.5811             7              2001.0
# 905         80.0   24.3500    73.7477             1              2001.0
# 906         16.5    9.9344    77.4768             7              2001.0
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# ...

# %%
#data loss
(907-833)/907*100
# Out:
# 8.158765159867695

# %%
# 8.15% of data loss is acceptable

# %%
# now we will split the feature and the label

# %%
x=df2.drop(columns=['capacity_mw'])
y=df2['capacity_mw']

# %%
x
# Out:
#      latitude  longitude  primary_fuel  commissioning_year  source  \
# 0     28.1839    73.2407             6              2011.0     109
# 1     24.7663    74.6090             1              2001.0     174
# 2     21.9038    69.3732             7              2001.0      21
# 3     23.8712    91.3602             2              2004.0      22
# 4     21.9603    82.4091             1              2015.0      22
# ..        ...        ...           ...                 ...     ...
# 902   16.2949    77.3568             1              2016.0      22
# 903   12.8932    78.1654             6              2001.0      77
# 904   15.2758    75.5811             7              2001.0      21
# 905   24.3500    73.7477             1              2001.0      59
# 906    9.9344    77.4768             7              2001.0      21
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0                     1          2431.823590          2428.226946
# ...

# %%
y
# Out:
# 0         2.5
# 1        98.0
# 2        39.2
# 3       135.0
# 4      1800.0
#         ...
# 902    1600.0
# 903       3.0
# 904      25.5
# 905      80.0
# 906      16.5
# Name: capacity_mw, Length: 833, dtype: float64

# %%
# 'x' are our features
# 'y' is our target varibale

# %%
x.skew()
# Out:
# latitude              -0.116170
# longitude              0.909304
# primary_fuel           0.411447
# commissioning_year    -1.266675
# source                 1.782665
# geolocation_source    -2.102192
# generation_gwh_2014    1.523020
# generation_gwh_2015    1.388494
# generation_gwh_2016    1.411175
# generation_gwh_2017    1.278034
# generation_gwh_2018    1.315084
# dtype: float64

# %%
# let's deal with the skewness

# %%
from sklearn.preprocessing import PowerTransformer
yj = PowerTransformer(method = 'yeo-johnson')

# %%
ss=['commissioning_year','source','geolocation_source','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018']

# %%
x[ss] = yj.fit_transform(x[ss].values)

# %%
x.skew()
# Out:
# latitude              -0.116170
# longitude              0.909304
# primary_fuel           0.411447
# commissioning_year    -0.315826
# source                -0.178437
# geolocation_source    -2.074065
# generation_gwh_2014   -0.250359
# generation_gwh_2015   -0.313329
# generation_gwh_2016   -0.312876
# generation_gwh_2017   -0.343626
# generation_gwh_2018   -0.356983
# dtype: float64

# %%
# the data looks better than before.

# %%
# now we will standardise the data.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaled_x = sc.fit_transform(x)
scaled_x
# Out:
# array([[ 1.16045784, -0.88846717,  1.16937695, ...,  0.36580495,
#          0.36652905,  0.38170588],
#        [ 0.6019911 , -0.57101686, -0.98951267, ...,  0.36580495,
#          0.36652905,  0.38170588],
#        [ 0.13423272, -1.7857405 ,  1.60115487, ...,  0.36580495,
#          0.36652905,  0.38170588],
#        ...,
#        [-0.9488424 , -0.34548631,  1.60115487, ...,  0.36580495,
#          0.36652905,  0.38170588],
#        [ 0.53396392, -0.77084143, -0.98951267, ...,  0.36580495,
#          0.36652905,  0.38170588],
#        [-1.82167545,  0.09432263,  1.60115487, ...,  0.36580495,
#          0.36652905,  0.38170588]])

# %%
xx=pd.DataFrame(scaled_x,columns=x.columns)

# %%
xx
# Out:
#      latitude  longitude  primary_fuel  commissioning_year    source  \
# 0    1.160458  -0.888467      1.169377            1.148978  1.613712
# 1    0.601991  -0.571017     -0.989513            0.004001  2.087889
# 2    0.134233  -1.785741      1.601155            0.004001 -0.468791
# 3    0.455724   3.315319     -0.557735            0.320411 -0.400650
# 4    0.143465   1.238633     -0.989513            1.685448 -0.400650
# ..        ...        ...           ...                 ...       ...
# 828 -0.782312   0.066482     -0.989513            1.827386 -0.400650
# 829 -1.338181   0.254080      1.169377            0.004001  1.229535
# 830 -0.948842  -0.345486      1.601155            0.004001 -0.468791
# 831  0.533964  -0.770841     -0.989513            0.004001  0.915820
# 832 -1.821675   0.094323      1.601155            0.004001 -0.468791
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0             -2.279786             0.332872             0.362399
# ...

# %%
# check the vif values

# %%
vif=pd.DataFrame()
vif['Vif values']=[variance_inflation_factor(xx.values,i)
                    for i in range(len(xx.columns))]
vif["features"]=xx.columns

# %%
vif
# Out:
#     Vif values             features
# 0     1.071836             latitude
# 1     1.275502            longitude
# 2     1.554714         primary_fuel
# 3     1.091026   commissioning_year
# 4     1.302290               source
# 5     1.715353   geolocation_source
# 6     4.161509  generation_gwh_2014
# 7     7.983223  generation_gwh_2015
# 8    11.873743  generation_gwh_2016
# 9    11.488934  generation_gwh_2017
# 10   12.247546  generation_gwh_2018

# %%
xx=xx.drop(columns=['generation_gwh_2018'])

# %%
vif=pd.DataFrame()
vif['Vif values']=[variance_inflation_factor(xx.values,i)
                    for i in range(len(xx.columns))]
vif["features"]=xx.columns

# %%
vif
# Out:
#    Vif values             features
# 0    1.071836             latitude
# 1    1.275002            longitude
# 2    1.554480         primary_fuel
# 3    1.090457   commissioning_year
# 4    1.301428               source
# 5    1.714922   geolocation_source
# 6    4.126455  generation_gwh_2014
# 7    7.967158  generation_gwh_2015
# 8   10.991042  generation_gwh_2016
# 9    5.542164  generation_gwh_2017

# %%
xx=xx.drop(columns=['generation_gwh_2016'])

# %%
vif=pd.DataFrame()
vif['Vif values']=[variance_inflation_factor(xx.values,i)
                    for i in range(len(xx.columns))]
vif["features"]=xx.columns

# %%
vif
# Out:
#    Vif values             features
# 0    1.071142             latitude
# 1    1.266569            longitude
# 2    1.554341         primary_fuel
# 3    1.073586   commissioning_year
# 4    1.301306               source
# 5    1.714811   geolocation_source
# 6    4.125969  generation_gwh_2014
# 7    5.149864  generation_gwh_2015
# 8    2.945705  generation_gwh_2017

# %%
# now tere is no multicolinearity problem.

# %%
# now we will build the model

# %% [markdown]
# # model building

# %%
# importing thee necessary libraries
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
xx
# Out:
#      latitude  longitude  primary_fuel  commissioning_year    source  \
# 0    1.160458  -0.888467      1.169377            1.148978  1.613712
# 1    0.601991  -0.571017     -0.989513            0.004001  2.087889
# 2    0.134233  -1.785741      1.601155            0.004001 -0.468791
# 3    0.455724   3.315319     -0.557735            0.320411 -0.400650
# 4    0.143465   1.238633     -0.989513            1.685448 -0.400650
# ..        ...        ...           ...                 ...       ...
# 828 -0.782312   0.066482     -0.989513            1.827386 -0.400650
# 829 -1.338181   0.254080      1.169377            0.004001  1.229535
# 830 -0.948842  -0.345486      1.601155            0.004001 -0.468791
# 831  0.533964  -0.770841     -0.989513            0.004001  0.915820
# 832 -1.821675   0.094323      1.601155            0.004001 -0.468791
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0             -2.279786             0.332872             0.362399
# ...

# %%
y
# Out:
# 0         2.5
# 1        98.0
# 2        39.2
# 3       135.0
# 4      1800.0
#         ...
# 902    1600.0
# 903       3.0
# 904      25.5
# 905      80.0
# 906      16.5
# Name: capacity_mw, Length: 833, dtype: float64

# %%
maxAcc = 0
maxRS = 0

for i in range(1,60):
    xtrain,xtest,ytrain,ytest = train_test_split(xx,y,test_size = .25, random_state=i)
    lg = LinearRegression()
    lg.fit(xtrain,ytrain)
    pred = lg.predict(xtest)
    acc = r2_score(ytest,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRs=i
print("Best Accuracy is:", maxAcc, "on Random State:", maxRs)
# Out:
# Best Accuracy is: 0.5109050600851612 on Random State: 34

# %%
# the best random state  is 34

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xx,y,test_size=0.25,random_state=34)

# %%
# LINEAR REGRESSION

from sklearn.metrics import mean_squared_error, mean_absolute_error
lr = LinearRegression()
lr.fit(xtrain, ytrain)
lpred = lr.predict(xtest)
print(r2_score(ytest, lpred))
print("Mean absolute error: ", mean_absolute_error(ytest,lpred))
print("Mean squared error: ", mean_squared_error(ytest,lpred))
# Out:
# 0.5109050600851612
# Mean absolute error:  221.31769011192043
# Mean squared error:  85087.79273566355

# %%
# RANDOMFOREST REGRESSOR

r= RandomForestRegressor()
r.fit(xtrain, ytrain)
rpred = r.predict(xtest)
print(r2_score(ytest, rpred))
print("Mean absolute error: ", mean_absolute_error(ytest,rpred))
print("Mean squared error: ", mean_squared_error(ytest,rpred))
# Out:
# 0.829597468826258
# Mean absolute error:  97.12978519408189
# Mean squared error:  29644.909547967127

# %%
# DECISIONTREE REGRESSOR

dt= DecisionTreeRegressor()
dt.fit(xtrain, ytrain)
dpred = dt.predict(xtest)
print(r2_score(ytest, dpred))
print("Mean absolute error: ", mean_absolute_error(ytest,dpred))
print("Mean squared error: ", mean_squared_error(ytest,dpred))
# Out:
# 0.7215429594464827
# Mean absolute error:  122.2786135034556
# Mean squared error:  48443.14062322831

# %%
# ADABOOST REGRESSOR
a=AdaBoostRegressor()
a.fit(xtrain,ytrain)
apred=a.predict(xtest)
print(r2_score(ytest, apred))
print("Mean absolute error: ", mean_absolute_error(ytest,apred))
print("Mean squared error: ", mean_squared_error(ytest,apred))
# Out:
# 0.6256177045418316
# Mean absolute error:  223.75203450453304
# Mean squared error:  65131.24663565982

# %% [markdown]
# # CrossValidation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# Linear Regression

s=cross_val_score(lr,xx,y)
print(s)
print(s.mean())
# Out:
# [0.24642884 0.41800778 0.34313984 0.48663807 0.43968893]
# 0.38678069204982235

# %%
# RandomForest Regressor

s=cross_val_score(r,xx,y)
print(s)
print(s.mean())
# Out:
# [0.78384903 0.81675768 0.6738523  0.75210437 0.79692915]
# 0.7646985052783377

# %%
# DecisionTree Regressor

s=cross_val_score(dt,xx,y)
print(s)
print(s.mean())
# Out:
# [0.71213064 0.30351308 0.65094695 0.53472934 0.69869255]
# 0.5800025111611767

# %%
# Adaboost Regressor

s=cross_val_score(a,xx,y)
print(s)
print(s.mean())
# Out:
# [0.59445354 0.62636239 0.58013521 0.62228039 0.64231041]
# 0.6131083892424007

# %%
# as per the observation, RandomForest Regressor is the best model of all.

# %%
param = {'n_estimators':[50,60,70],'max_depth': [10,15,20],
            'criterion':['mse','mae'],'min_samples_leaf': [5,10,15],
             'min_samples_split':[5,10,15,20],
             'max_features':["auto","sqrt","log2"]}
gcs=GridSearchCV(r,param,cv=5)
gcs.fit(xtrain,ytrain)
gcs.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 10,
#  'max_features': 'log2',
#  'min_samples_leaf': 5,
#  'min_samples_split': 10,
#  'n_estimators': 70}

# %%
fmodel1=RandomForestRegressor(max_features='log2',criterion='mse',min_samples_leaf=5,min_samples_split=10,max_depth=10,n_estimators=70)

# %%
fmodel1.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(criterion='mse', max_depth=10, max_features='log2',
#                       min_samples_leaf=5, min_samples_split=10,
#                       n_estimators=70)

# %%
pred1=fmodel1.predict(xtest)
acc=r2_score(ytest,pred1)
print(acc*100)
# Out:
# 83.1979555566027

# %%
# the Randomforest Regressor gives the accuracy of 83.19%

# %%
# save the model

# %%
import joblib
joblib.dump(fmodel1,'global_powerplant_capicity_mw')
# Out:
# ['global_powerplant_capicity_mw']

# %%
#load the model

# %%
p = joblib.load("global_powerplant_capicity_mw")
print(p.predict(xtest))
# Out:
# [  21.0946115    30.72233782   17.66755248  524.29225984   93.48726565
#   309.32036067  751.15484053   19.37226037   17.64285926   30.79902533
#   948.1282302    90.50925239  309.30138942   34.13466555  870.42618124
#  1200.95132524   26.44077808   47.46873456   69.78253286   13.5317766
#   428.77829001   20.1731872   321.55953507   40.08296745   71.48851545
#    25.26131664   14.14907655   39.04038474   10.88611343   97.94351136
#   324.69759254   37.79830761   18.65880579   29.64344194  219.70770344
#    82.33881407   13.02793908  411.2503108    40.26616338  718.31097839
#    26.20597052 1337.79060486  601.86234821  102.7423603    34.40744397
#   159.90475952 1086.88825592   44.93861389   36.98459106  300.55961947
#   344.91105905  319.57134305  761.54464364  380.53032608  380.23885698
#   309.49113419   47.46873456   84.59370136   31.08126268   28.40603562
#    21.57387061  123.25817878   27.32225249   18.31662292  755.66335993
# ...

# %%
#predicted values
print('predicted values:-',pred1)
print('actual values:-',ytest)
# Out:
# predicted values:- [  21.0946115    30.72233782   17.66755248  524.29225984   93.48726565
#   309.32036067  751.15484053   19.37226037   17.64285926   30.79902533
#   948.1282302    90.50925239  309.30138942   34.13466555  870.42618124
#  1200.95132524   26.44077808   47.46873456   69.78253286   13.5317766
#   428.77829001   20.1731872   321.55953507   40.08296745   71.48851545
#    25.26131664   14.14907655   39.04038474   10.88611343   97.94351136
#   324.69759254   37.79830761   18.65880579   29.64344194  219.70770344
#    82.33881407   13.02793908  411.2503108    40.26616338  718.31097839
#    26.20597052 1337.79060486  601.86234821  102.7423603    34.40744397
#   159.90475952 1086.88825592   44.93861389   36.98459106  300.55961947
#   344.91105905  319.57134305  761.54464364  380.53032608  380.23885698
#   309.49113419   47.46873456   84.59370136   31.08126268   28.40603562
#    21.57387061  123.25817878   27.32225249   18.31662292  755.66335993
# ...

# %%
d=pd.DataFrame({'predicted values':pred1,'actual values':ytest})

# %%
d
# Out:
#      predicted values  actual values
# 741         21.094612            4.0
# 430         30.722338           12.0
# 731         17.667552            3.3
# 237        524.292260          768.0
# 714         93.487266           70.0
# ..                ...            ...
# 221        125.362877          115.0
# 477        318.726553          246.0
# 270         18.474396           20.0
# 759         18.400730            8.5
# 515         47.537298           78.9
#
# [209 rows x 2 columns]
